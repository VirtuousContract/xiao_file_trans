# %%
import cv2
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

img=cv2.imread('girl.jpg')

# fig=plt.figure()
# ax = fig.gca(projection='3d')
# # plt.figure(figsize=(10,10))
# X=np.array(range(0,img.shape[0]))
# Y=np.array(range(0,img.shape[1]))
# X, Y = np.meshgrid(X, Y)
# # Z=[img[x,y] for x in X for y in Y]
# # ax.scatter(X,Y,img,marker='o')
# R = np.sqrt(X**2 + Y**2)
# Z = np.sin(R)
# surf = ax.plot_surface(X, Y, img,cmap=cm.coolwarm,linewidth=0, antialiased=False)
# # fig.colorbar(surf, shrink=0.5, aspect=5)
plt.imshow(img)

plt.show()

# %%
import numpy as np
import cv2
img=cv2.imread('girl.jpg',0)
X=np.array(range(0,img.shape[0]))
Y=np.array(range(0,img.shape[1]))
X, Y = np.meshgrid(X, Y)
X
# Z=[img[x,y] for x in X for y in Y]
# Out:
# array([[  0,   1,   2, ..., 447, 448, 449],
#        [  0,   1,   2, ..., 447, 448, 449],
#        [  0,   1,   2, ..., 447, 448, 449],
#        ...,
#        [  0,   1,   2, ..., 447, 448, 449],
#        [  0,   1,   2, ..., 447, 448, 449],
#        [  0,   1,   2, ..., 447, 448, 449]])

# %%
ax.scatter(X,Y,img,marker='o')

plt.show()

# %%
Z.shape
# Out:
# (742, 450)

# %%
img.shape
# Out:
# (450, 742)
